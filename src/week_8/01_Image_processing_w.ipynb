# %%
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
from skimage.exposure import histogram
from skimage.color import rgb2gray
from skimage import color
from skimage import io

img = plt.imread('Altstadt-Dresden-1180x786.jpg')
imgGray = rgb2gray(img)
print(imgGray.shape)
R , C = imgGray.shape

newImg = np.zeros(imgGray.shape)

# plt.imshow(img)
# plt.imshow(imgGray)

# grayscale
for r in range(R):
    for c in range(C):
#         newImg[r,c] = max([0,imgGray[r,c] -128/255])
#         newImg[r,c] = max([0,imgGray[r,c]/2])
        newImg[r,c] = max([0,1-imgGray[r,c]])

        
plt.imshow(newImg, cmap=plt.cm.gray)
# Out:
# (786, 1180)

# %%
# darken
for r in range(R):
    for c in range(C):
        #         newImg[r,c] = max([0,imgGray[r,c] -128/255])
        #         newImg[r,c] = max([0,imgGray[r,c]/2])
        newImg[r,c] = imgGray[r,c]-128


plt.imshow(newImg, cmap=plt.cm.gray)

# %%
# darken
for r in range(R):
    for c in range(C):
        #         newImg[r,c] = max([0,imgGray[r,c] -128/255])
        #         newImg[r,c] = max([0,imgGray[r,c]/2])
        newImg[r,c] = imgGray[r,c]/2


plt.imshow(newImg, cmap=plt.cm.gray)
